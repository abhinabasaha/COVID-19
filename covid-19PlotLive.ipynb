# %%
import sys
import time
import random
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import pandas as pd
import seaborn as sns
#import tabula
import pygal

# %%
stock_url  = 'https://www.mohfw.gov.in/'
response = requests.get(stock_url)
#print(response)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
data_array = list(soup.find(id='cases').getText().strip().split("\n"))

# %%
data = []
for i in range(27):
    data.append([])

# %%
for item in data_array:
    if 'Andhra Pradesh' in item:
        idx = data_array.index(item)
        data[0].append(data_array[idx])
        data[0].append(int(data_array[idx+1]))
        data[0].append(int(data_array[idx+3]))
        data[0].append(int(data_array[idx+4]))
    if 'Andaman and Nicobar Islands' in item:
        idx = data_array.index(item)
        data[1].append(data_array[idx])
        data[1].append(data_array[idx+1])
        data[1].append(data_array[idx+3])
        data[1].append(data_array[idx+4])
    if 'Bihar' in item:
        idx = data_array.index(item)
        data[2].append(data_array[idx])
        data[2].append(data_array[idx+1])
        data[2].append(data_array[idx+3])
        data[2].append(data_array[idx+4])
    if 'Chandigarh' in item:
        idx = data_array.index(item)
        data[3].append(data_array[idx])
        data[3].append(data_array[idx+1])
        data[3].append(data_array[idx+3])
        data[3].append(data_array[idx+4])
    if 'Chhattisgarh' in item:
        idx = data_array.index(item)
        data[4].append(data_array[idx])
        data[4].append(data_array[idx+1])
        data[4].append(data_array[idx+3])
        data[4].append(data_array[idx+4])
    if 'Delhi' in item:
        idx = data_array.index(item)
        data[5].append(data_array[idx])
        data[5].append(data_array[idx+1])
        data[5].append(data_array[idx+3])
        data[5].append(data_array[idx+4])
    if 'Goa' in item:
        idx = data_array.index(item)
        data[6].append(data_array[idx])
        data[6].append(data_array[idx+1])
        data[6].append(data_array[idx+3])
        data[6].append(data_array[idx+4])
    if 'Gujarat' in item:
        idx = data_array.index(item)
        data[7].append(data_array[idx])
        data[7].append(data_array[idx+1])
        data[7].append(data_array[idx+3])
        data[7].append(data_array[idx+4])
    if 'Haryana' in item:
        idx = data_array.index(item)
        data[8].append(data_array[idx])
        data[8].append(data_array[idx+1])
        data[8].append(data_array[idx+3])
        data[8].append(data_array[idx+4])
    if 'Himachal Pradesh' in item:
        idx = data_array.index(item)
        data[9].append(data_array[idx])
        data[9].append(data_array[idx+1])
        data[9].append(data_array[idx+3])
        data[9].append(data_array[idx+4])
    if 'Jammu and Kashmir' in item:
        idx = data_array.index(item)
        data[10].append(data_array[idx])
        data[10].append(data_array[idx+1])
        data[10].append(data_array[idx+3])
        data[10].append(data_array[idx+4])
    if 'Karnataka' in item:
        idx = data_array.index(item)
        data[11].append(data_array[idx])
        data[11].append(data_array[idx+1])
        data[11].append(data_array[idx+3])
        data[11].append(data_array[idx+4])
    if 'Kerala' in item:
        idx = data_array.index(item)
        data[12].append(data_array[idx])
        data[12].append(data_array[idx+1])
        data[12].append(data_array[idx+3])
        data[12].append(data_array[idx+4])
    if 'Ladakh' in item:
        idx = data_array.index(item)
        data[13].append(data_array[idx])
        data[13].append(data_array[idx+1])
        data[13].append(data_array[idx+3])
        data[13].append(data_array[idx+4])
    if 'Madhya Pradesh' in item:
        idx = data_array.index(item)
        data[14].append(data_array[idx])
        data[14].append(data_array[idx+1])
        data[14].append(data_array[idx+3])
        data[14].append(data_array[idx+4])
    if 'Maharashtra' in item:
        idx = data_array.index(item)
        data[15].append(data_array[idx])
        data[15].append(data_array[idx+1])
        data[15].append(data_array[idx+3])
        data[15].append(data_array[idx+4])
    if 'Manipur' in item:
        idx = data_array.index(item)
        data[16].append(data_array[idx])
        data[16].append(data_array[idx+1])
        data[16].append(data_array[idx+3])
        data[16].append(data_array[idx+4])
    if 'Mizoram' in item:
        idx = data_array.index(item)
        data[17].append(data_array[idx])
        data[17].append(data_array[idx+1])
        data[17].append(data_array[idx+3])
        data[17].append(data_array[idx+4])
    if 'Odisha' in item:
        idx = data_array.index(item)
        data[18].append(data_array[idx])
        data[18].append(data_array[idx+1])
        data[18].append(data_array[idx+3])
        data[18].append(data_array[idx+4])
    if 'Puducherry' in item:
        idx = data_array.index(item)
        data[19].append(data_array[idx])
        data[19].append(data_array[idx+1])
        data[19].append(data_array[idx+3])
        data[19].append(data_array[idx+4])
    if 'Punjab' in item:
        idx = data_array.index(item)
        data[20].append(data_array[idx])
        data[20].append(data_array[idx+1])
        data[20].append(data_array[idx+3])
        data[20].append(data_array[idx+4])
    if 'Rajasthan' in item:
        idx = data_array.index(item)
        data[21].append(data_array[idx])
        data[21].append(data_array[idx+1])
        data[21].append(data_array[idx+3])
        data[21].append(data_array[idx+4])
    if 'Tamil Nadu' in item:
        idx = data_array.index(item)
        data[22].append(data_array[idx])
        data[22].append(data_array[idx+1])
        data[22].append(data_array[idx+3])
        data[22].append(data_array[idx+4])
    if 'Telengana' in item:
        idx = data_array.index(item)
        data[23].append(data_array[idx])
        data[23].append(data_array[idx+1])
        data[23].append(data_array[idx+3])
        data[23].append(data_array[idx+4])
    if 'Uttarakhand' in item:
        idx = data_array.index(item)
        data[24].append(data_array[idx])
        data[24].append(data_array[idx+1])
        data[24].append(data_array[idx+3])
        data[24].append(data_array[idx+4])
    if 'Uttar Pradesh' in item:
        idx = data_array.index(item)
        data[25].append(data_array[idx])
        data[25].append(data_array[idx+1])
        data[25].append(data_array[idx+3])
        data[25].append(data_array[idx+4])
    if 'West Bengal' in item:
        idx = data_array.index(item)
        data[26].append(data_array[idx])
        data[26].append(data_array[idx+1])
        data[26].append(data_array[idx+3])
        data[26].append(data_array[idx+4])

# %%
df = pd.DataFrame(data)
df = df.rename(columns={0: 'State', 1: 'Total Confirmed cases', 2: 'Cured / Discharged / Migrated', 3: 'Death'})
df
# Out:
#                           State Total Confirmed cases  \
# 0                Andhra Pradesh                    19
# 1   Andaman and Nicobar Islands                     9
# 2                         Bihar                    11
# 3                    Chandigarh                     8
# 4                  Chhattisgarh                     7
# 5                         Delhi                    53
# 6                           Goa                     5
# 7                       Gujarat                    58
# 8                       Haryana                    33
# 9              Himachal Pradesh                     3
# 10            Jammu and Kashmir                    31
# 11                    Karnataka                    80
# 12                       Kerala                   194
# 13                       Ladakh                    13
# 14               Madhya Pradesh                    33
# 15                  Maharashtra                   193
# ...

# %%
df1 = df.melt('State', var_name='Cases',  value_name='Counts')

# %%
# %matplotlib inline
plt.figure(figsize=(10,15))
g = sns.barplot(x="Counts", y="State", hue='Cases', data=df1)
